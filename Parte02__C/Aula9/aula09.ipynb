# %%
# %pip install pandas
# %pip installopenpyxl

import pandas as pd

df = pd.read_csv('aula9.csv')
print(df)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "installopenpyxl" - maybe you meant "install"
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 4
#       1 get_ipython().run_line_magic('pip', 'install pandas')
#       2 get_ipython().run_line_magic('pip', 'installopenpyxl')
#       3
# ----> 4 import pandas as pd
#       5
#       6 df = pd.read_csv('aula9.csv')
#       7 print(df)
#
# File c:\Users\camila.kaufman\Documents\CamilaKaufmam\senac-data-analytics\venv\Lib\site-packages\pandas\__init__.py:31
#      28         _missing_dependencies.append(f"{_dependency}: {_e}")
# ...
