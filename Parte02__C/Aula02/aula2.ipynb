# %%
import pandas as pd

lista_precos = [100, 150, 200,50]

#print(lista_precos)

#lista_com_desconto = [preco * 0.9 for preco in lista_precos]
#print(lista_com_desconto)

serie_precos = pd.Series(lista_precos)
print(serie_precos)

serie_com_desconto = serie_precos * 0.9
print(serie_com_desconto)
# Out:
# 0    100
# 1    150
# 2    200
# 3     50
# dtype: int64
# 0     90.0
# 1    135.0
# 2    180.0
# 3     45.0
# dtype: float64
