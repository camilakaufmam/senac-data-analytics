# %%
import sqlite3
import pandas as pd
import numpay as np


#JSON
# # import json
# df_custos = pd.read_json("custos_operacionais.json")

#Lendo o arquivo JSON
#with open("custos_operacionais.json", "r", encoding="utf-8") as arquivo:
    #custos_json = json.load(arquivo)

#Transformando em dataframe
df_custos = pd.DataFrame(custos_json).T.reset_index()
df_custos.rename(columns={"index": "filial"}, inplace=True)
#print(df_custos)


# SQL
#Connection = sqlite3.connect('DataOrganized.db')
#cursor = connection.cursor()
#cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name != 'sqlite_sequence'")
#tabelas = cursor.fetchall()
#print(tabelas)
#query = """
#SELECT 
#    v.id_venda,
#    v.quantidade,
#    v.preco_venda,
#    v.data_venda,
# #     v.vendedor,
# #     v.filial,
# #     p.nome_produto,  
# #     p.categoria,
# #     p.preco_tabela
# # FROM
# #     vendas v
# # INNER JOIN
# #     produtos p ON v.id_produto = p.id_produto;
#  """
#df_vendas_produtos = pd.read_sql_query(query, connection)
#print(df_vendas_produtos.head())
#connection.close()


#EXCEL
# df_vendas = pd.read_excel("metas_vendas_2024.xlsx")
# df_vendas.rename(columns={"Filial": "filial"}, inplace=True)
# #print(df_vendas.head())

#CSV

df_satisfacao = pd.read_csv("pesquisa_satisfacao_clientes.csv")
df_satisfacao.rename(columns={"Filial": "filial"}, inplace=True)
print(df_satisfacao.head())


#juncao = pd.merge(df_clientes, df_vendas, df_vendas_produtos, df_custos)
#print(juncao)
# Out:
#    ID_Cliente filial  Nota             Comentario
# 0        8270     SP     5  Excelente atendimento
# 1        6390     SP     5  Excelente atendimento
# 2        6734     SP     5  Excelente atendimento
# 3        5426     SP     5  Excelente atendimento
# 4        9322     SP     4  Excelente atendimento

# %%
#   MERGE
